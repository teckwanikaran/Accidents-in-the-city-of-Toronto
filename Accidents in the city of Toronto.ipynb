# %% [markdown]
# <h1 align = 'center'> Accidents in the city of Toronto </h1>
#
# <b> Notebook by [Karan Teckwani](https://karanteckwani.com) </b>
# - [LinkedIn](https://www.linkedin.com/in/karanteckwani/)
# - [Github](https://github.com/teckwanikaran)
# - [Twitter](https://twitter.com/karanteckwani)

# %% [markdown]
# Accidents!! They can happen all the time to any person located anywhere in the world. In this project I will explore the [Toronto police Killed or Seriously Injured dataset](http://data.torontopolice.on.ca/datasets/ksi/data). This dataset contains the information about accident in the city of Toronto from 2006 - 2016. So Let's dive in!!

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Python-Libraries" data-toc-modified-id="Python-Libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Python Libraries</a></span></li><li><span><a href="#Import-the-Libraries" data-toc-modified-id="Import-the-Libraries-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Import the Libraries</a></span></li><li><span><a href="#Download-and-Import-the-data" data-toc-modified-id="Download-and-Import-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Download and Import the data</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Time-&amp;-Age-Related-Data" data-toc-modified-id="Time-&amp;-Age-Related-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Time &amp; Age Related Data</a></span></li><li><span><a href="#Location-Related-Data" data-toc-modified-id="Location-Related-Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Location Related Data</a></span></li><li><span><a href="#Road-Conditions" data-toc-modified-id="Road-Conditions-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Road Conditions</a></span></li><li><span><a href="#Weather-Conditions" data-toc-modified-id="Weather-Conditions-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Weather Conditions</a></span></li><li><span><a href="#Injury-Information" data-toc-modified-id="Injury-Information-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Injury Information</a></span></li><li><span><a href="#Types-of-Transporation-involved-in-collision" data-toc-modified-id="Types-of-Transporation-involved-in-collision-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Types of Transporation involved in collision</a></span></li><li><span><a href="#Details-and-Reasons-of-Accident" data-toc-modified-id="Details-and-Reasons-of-Accident-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Details and Reasons of Accident</a></span><ul class="toc-item"><li><span><a href="#Automobile-related-information" data-toc-modified-id="Automobile-related-information-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Automobile related information</a></span></li><li><span><a href="#Pedestrian-related-information" data-toc-modified-id="Pedestrian-related-information-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Pedestrian related information</a></span></li><li><span><a href="#Cyclist-related-information" data-toc-modified-id="Cyclist-related-information-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Cyclist related information</a></span></li><li><span><a href="#Reasons-involved-in-the-accident" data-toc-modified-id="Reasons-involved-in-the-accident-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>Reasons involved in the accident</a></span></li></ul></li><li><span><a href="#Index-Columns" data-toc-modified-id="Index-Columns-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Index Columns</a></span></li></ul></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#DATE" data-toc-modified-id="DATE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>DATE</a></span></li><li><span><a href="#INVAGE" data-toc-modified-id="INVAGE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>INVAGE</a></span></li><li><span><a href="#Empty-string" data-toc-modified-id="Empty-string-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Empty string</a></span></li><li><span><a href="#Fill-NaN" data-toc-modified-id="Fill-NaN-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Fill NaN</a></span></li><li><span><a href="#LIGHT" data-toc-modified-id="LIGHT-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>LIGHT</a></span></li><li><span><a href="#Create-new-DF" data-toc-modified-id="Create-new-DF-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Create new DF</a></span></li></ul></li><li><span><a href="#Data-Visualization" data-toc-modified-id="Data-Visualization-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Visualization</a></span><ul class="toc-item"><li><span><a href="#Time-and-Age-of-person-involved-in-the-accident" data-toc-modified-id="Time-and-Age-of-person-involved-in-the-accident-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Time and Age of person involved in the accident</a></span></li><li><span><a href="#Location-of-Accident" data-toc-modified-id="Location-of-Accident-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Location of Accident</a></span></li><li><span><a href="#Road-Type-and-conditions-during-accident" data-toc-modified-id="Road-Type-and-conditions-during-accident-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Road Type and conditions during accident</a></span></li><li><span><a href="#Weather-conditions-during-accident" data-toc-modified-id="Weather-conditions-during-accident-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Weather conditions during accident</a></span></li><li><span><a href="#Injury-type-of-the-accident" data-toc-modified-id="Injury-type-of-the-accident-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Injury type of the accident</a></span></li><li><span><a href="#Types-of-Transporation" data-toc-modified-id="Types-of-Transporation-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Types of Transporation</a></span></li><li><span><a href="#Reason-of-Accident" data-toc-modified-id="Reason-of-Accident-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Reason of Accident</a></span></li><li><span><a href="#Automobile-related-Information" data-toc-modified-id="Automobile-related-Information-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Automobile related Information</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# * This dataset is open sourced by the Toronto Police and consists of all the traffic accident events from 2006 - 2016. The dataset can be found [here](http://data.torontopolice.on.ca/datasets/ksi).
#
# * The dataset is distributed under [Open Government Licence – Ontario](http://data.torontopolice.on.ca/pages/licence).
#
# * A detailed explanation about the dataset and its metadata information can be found [here](http://data.torontopolice.on.ca/pages/ksi).
#
# * The goal of this project is to perform:
#     * An Exploratory Data Analysis (EDA) of the killed and seriously injured (KSI) dataset.
#     * Perform Data Munging and Data Wrangling of the dataset.
#     * Draw insights from the clean dataset using various visualization graphs.
#     * Provide a brief summary.

# %% [markdown]
# ### Python Libraries

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# For installing Python on your laptop, use the [Anaconda Python distribution](http://continuum.io/downloads). The setup is very easy and user-friendly.
#
# The libraries that will be used for this project are mentioned below:
#
# * **[NumPy](http://www.numpy.org/)**: Provides a fast numerical array structure and helper functions.
# * **[Pandas](http://pandas.pydata.org/)**: Provides a DataFrame structure (table like) to store, observe, modify data.
# * **[Matplotlib](http://matplotlib.org/)**: The Basic plotting library in Python for data visualization
# * **[Seaborn](https://seaborn.pydata.org)**: Advanced statistical plotting library.
# * **[Folium](http://folium.readthedocs.io/en/latest/)**: To visualize the leaflet map.
# * **[Shapely](https://pypi.org/project/Shapely/)**: Provides function to manipulate and analyze geometric objects.
# * **[Json](https://docs.python.org/3/library/json.html)**: Provides the facility to encode and decode json files.
# * **[SciPy](http://www.scipy.org/)**: Mathematical functions built on the Numpy extension
# * **[StatsModels](http://statsmodels.sourceforge.net/)**: Provides tools to conduct statistical testing and statistical data exploration
# * **[SciKit-Learn](http://scikit-learn.org/stable/)**: The essential Machine Learning package in Python.
#
#
# To install any of the above mentioned library, you can add them with
#     1. conda: conda install numpy pandas scikit-learn matplotlib seaborn
#     2. pip: pip install numpy

# %% [markdown]
# ### Import the Libraries

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# - The first step is import the required libraries.

# %%
# Filter warnings
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter('ignore')
# Access file path
import os
# read csv file into pandas dataframe
import pandas as pd  
# perform matrix calculations
import numpy as np   
# Data visualization
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
sns.set(font_scale=1.2)
import matplotlib.style as style
# style.use('seaborn-talk') #sets the size of the charts

import json
import folium
from folium.plugins import HeatMap
from shapely.geometry import shape, Point

# %% [markdown]
# ### Download and Import the data

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# - The second step is to download the dataset from the above mentioned website into the "Data" folder of the working directory and load it into pandas dataframe.

# %%
data = pd.read_csv('Data/KSI.csv') 
data.head()
# Out:
#            X          Y    Index_      ACCNUM  YEAR                      DATE  \
# 0 -79.383490  43.651545   6666068     1249781  2011  2011-08-04T04:00:00.000Z
# 1 -79.300490  43.780445   7542240     1311542  2012  2012-08-19T04:00:00.000Z
# 2 -79.328266  43.682342  80496257  5002235651  2015  2015-12-30T05:00:00.000Z
# 3 -79.300490  43.780445   7542241     1311542  2012  2012-08-19T04:00:00.000Z
# 4 -79.300490  43.780445   7542242     1311542  2012  2012-08-19T04:00:00.000Z
#
#    TIME  Hour         STREET1      STREET2  ...   AG_DRIV REDLIGHT ALCOHOL  \
# 0  2318    23      QUEEN ST W      YORK ST  ...
# 1  2318    23  SHEPPARD AVE E  AMETHYST RD  ...       Yes
# 2  2339    23    DANFORTH AVE  GILLARD AVE  ...       Yes
# 3  2318    23  SHEPPARD AVE E  AMETHYST RD  ...       Yes
# 4  2318    23  SHEPPARD AVE E  AMETHYST RD  ...       Yes
#
#    DISABILITY  Division                     Ward_Name Ward_ID Hood_ID  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data.shape
# Out:
# (12557, 57)

# %% [markdown]
# - There are 12557 rows with 57 columns.

# %%
data.describe()
# Out:
#                   X             Y        Index_        ACCNUM          YEAR  \
# count  12557.000000  12557.000000  1.255700e+04  1.255700e+04  12557.000000
# mean     -79.395989     43.710715  2.799053e+07  1.576768e+09   2011.547822
# std        0.104216      0.056025  3.390049e+07  2.541023e+09      3.104151
# min      -79.638390     43.592048  0.000000e+00  1.284070e+05   2007.000000
# 25%      -79.467434     43.662645  5.398745e+06  1.108321e+06   2009.000000
# 50%      -79.396490     43.702345  7.376871e+06  1.276036e+06   2011.000000
# 75%      -79.318090     43.755992  8.021012e+07  4.002384e+09   2014.000000
# max      -79.125897     43.855445  8.079331e+07  7.003292e+09   2017.000000
#
#                TIME          Hour      LATITUDE     LONGITUDE      FATAL_NO  \
# count  12557.000000  12557.000000  12557.000000  12557.000000  12557.000000
# mean    1344.978020     13.167317     43.710715    -79.395989      1.252369
# ...

# %% [markdown]
# - Seems like the X,Y and LONGITUDE,LATITUDE are having the same values respectively.
# - Out of the 57 columns only 13 are numerical, from these 13 columns 2 are repeated and 4 are index, accident number, Id type of columns, which are very less likely to be useful to provide any insight into the dataset.

# %%
data.columns
# Out:
# Index(['X', 'Y', 'Index_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'Hour', 'STREET1',
#        'STREET2', 'OFFSET', 'ROAD_CLASS', 'District', 'LATITUDE', 'LONGITUDE',
#        'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND',
#        'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY', 'FATAL_NO',
#        'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDTYPE',
#        'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND', 'PEDESTRIAN',
#        'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH',
#        'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL',
#        'DISABILITY', 'Division', 'Ward_Name', 'Ward_ID', 'Hood_ID',
#        'Hood_Name', 'FID'],
#       dtype='object')

# %% [markdown]
# - The [metadata file](https://opendata.arcgis.com/datasets/d3bf69ee1e5841238627e5fcee083db5_0.csv) contains all the required information about the description of each column. According to the metadeta file description my plan is to divide the columns into 8 groups as follows:
#
#         2.1 Time & Age Related Data
#         a. YEAR   - Year of accident
#         b. DATE   - Date of accident
#         c. TIME   - Time of accident
#         d. Hour   - Hour of Accident
#         e. INVAGE - Age of involved party
#
#         2.2: Location Related Data
#         a. LATITUDE  - Latitude of accident
#         b. LONGITUDE - Longitude of accident
#         c. Division  - Police division
#         d. Ward_Name - City ward name
#         e. Ward_ID   - City ward Id
#         f. Hood_ID   - Neighbourhood Id
#         g. Hood_Name - Neighbourhood name
#         h. District  - City district
#         i. STREET1   - Street 1
#         j. STREET2   - Street 2
#         k. X         - May be Latitude
#         l. Y         - May be Longitude
#
#         2.3: Road Conditions
#         a. ROAD_CLASS - Road classification
#         b. LOCCOORD   - Location coordinate
#         c. ACCLOC     - Accident location
#         d. RDSFCOND   - Road surface condition
#         e. TRAFFCTL   - Traffic control type
#
#         2.4: Weather Conditions
#         a. VISIBILITY - Enviornment conditions
#         b. LIGHT      - Light conditions
#
#         2.5: Injury Information
#         a. ACCLASS   - Classificaiton of accident
#         b. IMPACTYPE - Initial imapact type
#         c. INVTYPE   - Involvement type
#         d. INJURY    - Severity of injury
#
#         2.6: Types of Transporation involved in collision
#         a. PEDESTRIAN - Pedestrian
#         b. CYCLIST    - Cyclists
#         c. AUTOMOBILE - Driver
#         d. MOTORCYCLE - Motorcyclist
#         e. TRUCK      - Truck driver
#         f. TRSN_CITY  - Transit vehicle
#         g. EMERG_VEH  - Emergency vehicle
#         h. PASSENGER  - Passenger
#         i. VEHTYPE    - Type of vehicle
#
#         2.7: Details and Reasons of Accident
#         a. INITDIR    - Initial direction of travel
#         b. MANOEUVER  - Vehicle manouever
#         c. DRIVACT    - Apparent driver action
#         d. DRIVCOND   - Driver condition
#         e. PEDTYPE    - Pedestrian crash type - detail
#         f. PEDACT     - Pedestrian action
#         g. PEDCOND    - Condition of pedestrian
#         h. CYCLISTYPE - Cyclist crash type - detail
#         i. CYCACT     - Cyclist action
#         j. CYCCOND    - Cyclist condition
#         k. SPEEDING   - Speeding related collision
#         l. AG_DRIV    - Aggressive & distracted driving
#         m. REDLIGHT   - Redlight related collision
#         n. ALCOHOL    - Alcohol related collision
#         o. DISABILITY - Disability related collision
#         p. OFFSET     - Distance & direction of the accident
#
#         2.8: Index Columns
#         a. Index_   - Index number
#         b. ACCNUM   - Accident number
#         c. FATAL_NO - Sequential number
#         d. FID      - Field Index number

# %% [markdown]
# ### Time & Age Related Data

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
# Let's observe the top few rows
data[['YEAR','DATE', 'TIME', 'Hour']].head()
# Out:
#    YEAR                      DATE  TIME  Hour
# 0  2011  2011-08-04T04:00:00.000Z  2318    23
# 1  2012  2012-08-19T04:00:00.000Z  2318    23
# 2  2015  2015-12-30T05:00:00.000Z  2339    23
# 3  2012  2012-08-19T04:00:00.000Z  2318    23
# 4  2012  2012-08-19T04:00:00.000Z  2318    23

# %%
data[['YEAR','DATE', 'TIME', 'Hour', 'INVAGE']].isnull().sum() 
# no missing values
# Out:
# YEAR      0
# DATE      0
# TIME      0
# Hour      0
# INVAGE    0
# dtype: int64

# %%
data[['YEAR','DATE', 'TIME', 'Hour', 'INVAGE']].info() 
# will have to change the dtype of DATE from object to DateTime format later
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12557 entries, 0 to 12556
# Data columns (total 5 columns):
# YEAR      12557 non-null int64
# DATE      12557 non-null object
# TIME      12557 non-null int64
# Hour      12557 non-null int64
# INVAGE    12557 non-null object
# dtypes: int64(3), object(2)
# memory usage: 490.6+ KB

# %%
data['INVAGE'].value_counts() 
# >2000 Unknown values
# In cleaning section, I will increase the bins from 5 yr to 25 yr
# Assign categorical values to new bins 0-24), 26-49) and so on.
# Out:
# unknown     2114
# 20 to 24    1134
# 25 to 29    1083
# 35 to 39     903
# 30 to 34     901
# 50 to 54     886
# 40 to 44     870
# 45 to 49     857
# 55 to 59     734
# 60 to 64     583
# 15 to 19     542
# 65 to 69     455
# 70 to 74     361
# 75 to 79     293
# 80 to 84     218
# 85 to 89     155
# 10 to 14     155
# 5 to 9       134
# 0 to 4       127
# 90 to 94      45
# Over 95        7
# Name: INVAGE, dtype: int64

# %% [markdown]
# ### Location Related Data

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# - In the metadata file there are only LONGITUDE AND LATITUDE columns and in the dataset there are X and Y columns as well, judging by the name of the columns it seems like X and Y should be having same values as LONGITUDE AND LATITUDE

# %%
data[['X', 'Y','LATITUDE', 'LONGITUDE']].head(10)
# Out:
#            X          Y   LATITUDE  LONGITUDE
# 0 -79.383490  43.651545  43.651545 -79.383490
# 1 -79.300490  43.780445  43.780445 -79.300490
# 2 -79.328266  43.682342  43.682342 -79.328266
# 3 -79.300490  43.780445  43.780445 -79.300490
# 4 -79.300490  43.780445  43.780445 -79.300490
# 5 -79.300490  43.780445  43.780445 -79.300490
# 6 -79.528515  43.625201  43.625201 -79.528515
# 7 -79.528515  43.625201  43.625201 -79.528515
# 8 -79.330190  43.663245  43.663245 -79.330190
# 9 -79.330190  43.663245  43.663245 -79.330190

# %% [markdown]
# - <b> Yes, Indeed they are same, therefore X and Y will later be droped in the Data Cleaning section.</b>

# %%
data[['LATITUDE','LONGITUDE', 'Division', 
      'Ward_Name', 'Ward_ID', 'Hood_ID', 'Hood_Name', 
      'District', 'STREET1', 'STREET2']].isnull().sum()
# Out:
# LATITUDE     0
# LONGITUDE    0
# Division     0
# Ward_Name    0
# Ward_ID      0
# Hood_ID      0
# Hood_Name    0
# District     0
# STREET1      0
# STREET2      0
# dtype: int64

# %%
data[['Division', 'Ward_Name', 'Ward_ID', 'Hood_ID', 
      'Hood_Name', 'District', 'STREET1', 'STREET2']].head()
# Out:
#   Division                     Ward_Name  Ward_ID  Hood_ID  \
# 0      D52  Toronto Centre-Rosedale (27)       27       76
# 1      D42    Scarborough-Agincourt (40)       40      118
# 2      D55         Toronto-Danforth (30)       30       65
# 3      D42    Scarborough-Agincourt (40)       40      118
# 4      D42    Scarborough-Agincourt (40)       40      118
#
#                       Hood_Name           District         STREET1  \
# 0      Bay Street Corridor (76)  Toronto East York      QUEEN ST W
# 1  Tam O'Shanter-Sullivan (118)        Scarborough  SHEPPARD AVE E
# 2        Greenwood-Coxwell (65)  Toronto East York    DANFORTH AVE
# 3  Tam O'Shanter-Sullivan (118)        Scarborough  SHEPPARD AVE E
# 4  Tam O'Shanter-Sullivan (118)        Scarborough  SHEPPARD AVE E
#
#        STREET2
# 0      YORK ST
# 1  AMETHYST RD
# 2  GILLARD AVE
# 3  AMETHYST RD
# 4  AMETHYST RD

# %%
data['Ward_Name'].value_counts()
# Out:
# Trinity-Spadina (20)            722
# Toronto Centre-Rosedale (28)    573
# Toronto Centre-Rosedale (27)    524
# Scarborough Southwest (35)      419
# Toronto-Danforth (30)           385
# Etobicoke North (2)             385
# Etobicoke North (1)             384
# Scarborough Centre (37)         376
# Scarborough-Rouge River (41)    371
# Scarborough-Rouge River (42)    354
# Scarborough Centre (38)         348
# Etobicoke-Lakeshore (5)         332
# Trinity-Spadina (19)            327
# Parkdale-High Park (14)         314
# Willowdale (23)                 302
# York South-Weston (11)          302
# Scarborough-Agincourt (40)      296
# Davenport (17)                  295
# Etobicoke-Lakeshore (6)         294
# York West (7)                   273
# York South-Weston (12)          261
# Willowdale (24)                 255
# York West (8)                   251
# Beaches-East York (32)          251
# Davenport (18)                  246
# St. Paul's (22)                 243
# ...

# %%
data['Hood_Name'].value_counts()
# Out:
# Waterfront Communities-The Island (77)      492
# West Humber-Clairville (1)                  427
# Bay Street Corridor (76)                    298
# Woburn (137)                                277
# South Riverdale (70)                        245
# Islington-City Centre West (14)             241
# Wexford/Maryvale (119)                      225
# Rouge (131)                                 214
# South Parkdale (85)                         197
# Clairlea-Birchmount (120)                   193
# Milliken (130)                              191
# Church-Yonge Corridor (75)                  185
# York University Heights (27)                180
# Downsview-Roding-CFB (26)                   180
# Kensington-Chinatown (78)                   176
# Dovercourt-Wallace Emerson-Junction (93)    170
# Tam O'Shanter-Sullivan (118)                164
# Annex (95)                                  163
# Bendale (127)                               159
# Moss Park (73)                              158
# ...

# %%
data['District'].value_counts()
# Out:
# Toronto East York    4200
# Etobicoke York       3004
# Scarborough          2940
# North York           2399
# No District            13
#                         1
# Name: District, dtype: int64

# %% [markdown]
# - The Division column will be helpful to create the choropleth map visualization of the accidents in the visualizaiton section. I will discuss later in detail. Also, I think District is the main subclass into which the city of Toronto is divided. Followed by subdivision into Ward and these Wards are subdivided into Hood (Neighborhoods).
#
# - The Ward_Name, Hood_Name, STREET1 and STREET2 are irrelevant to the analysis and therefore won't be considered for the analysis

# %% [markdown]
# ### Road Conditions

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['ROAD_CLASS', 'LOCCOORD', 'ACCLOC', 'RDSFCOND', 'TRAFFCTL']].head()
# Out:
#        ROAD_CLASS      LOCCOORD           ACCLOC RDSFCOND    TRAFFCTL
# 0  Major Arterial     Mid-Block                       Dry  No Control
# 1  Major Arterial  Intersection                       Dry  No Control
# 2  Major Arterial  Intersection  At Intersection      Dry  No Control
# 3  Major Arterial  Intersection                       Dry  No Control
# 4  Major Arterial  Intersection                       Dry  No Control

# %%
data[['ROAD_CLASS', 'LOCCOORD', 'ACCLOC', 'RDSFCOND', 'TRAFFCTL']].isnull().sum()
# Out:
# ROAD_CLASS    0
# LOCCOORD      0
# ACCLOC        0
# RDSFCOND      0
# TRAFFCTL      0
# dtype: int64

# %%
data.ROAD_CLASS.value_counts()
# Out:
# Major Arterial         8640
# Minor Arterial         2080
# Local                   705
# Collector               704
# Expressway              395
# Expressway Ramp          22
# Major Arterial Ramp       7
# Laneway                   4
# Name: ROAD_CLASS, dtype: int64

# %%
data.LOCCOORD.value_counts() 
# Very few blank values, which will be treated in data cleaning section
# Out:
# Intersection                           8331
# Mid-Block                              4137
#                                          85
# Entrance Ramp Westbound                   2
# Park, Private Property, Public Lane       2
# Name: LOCCOORD, dtype: int64

# %%
data.ACCLOC.value_counts() 
# There are too many blank values, I will just fill them using "Unknown"
# Out:
# At Intersection          5772
#                          4710
# Non Intersection         1218
# Intersection Related      676
# At/Near Private Drive     148
# Private Driveway           13
# Laneway                     9
# Underpass or Tunnel         6
# Overpass or Bridge          4
# Trail                       1
# Name: ACCLOC, dtype: int64

# %%
data.RDSFCOND.value_counts() 
# few missing values
# Out:
# Dry                     10025
# Wet                      2107
# Loose Snow                131
# Other                     107
# Slush                      77
# Ice                        57
# Packed Snow                40
#                             7
# Loose Sand or Gravel        5
# Spilled liquid              1
# Name: RDSFCOND, dtype: int64

# %%
data.TRAFFCTL.value_counts() 
# Very few blank values, which will be treated in data cleaning section
# Out:
# No Control              6032
# Traffic Signal          5277
# Stop Sign                972
# Pedestrian Crossover     140
# Traffic Controller        78
#                           24
# Streetcar (Stop for)      16
# Yield Sign                 9
# Traffic Gate               5
# School Guard               2
# Police Control             2
# Name: TRAFFCTL, dtype: int64

# %% [markdown]
# ### Weather Conditions

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['VISIBILITY', 'LIGHT']].head()
# Out:
#   VISIBILITY             LIGHT
# 0      Clear              Dark
# 1      Clear  Dark, artificial
# 2      Clear  Dark, artificial
# 3      Clear  Dark, artificial
# 4      Clear  Dark, artificial

# %%
data[['VISIBILITY', 'LIGHT']].isnull().sum()
# Out:
# VISIBILITY    0
# LIGHT         0
# dtype: int64

# %%
data.VISIBILITY.value_counts()
# Out:
# Clear                     10812
# Rain                       1301
# Snow                        281
# Other                        74
# Fog, Mist, Smoke, Dust       38
# Freezing Rain                31
# Drifting Snow                13
# Strong wind                   5
#                               2
# Name: VISIBILITY, dtype: int64

# %%
data.LIGHT.value_counts()
# Out:
# Daylight                7378
# Dark                    2754
# Dark, artificial        1902
# Dusk                     185
# Dusk, artificial         123
# Dawn                      77
# Daylight, artificial      68
# Dawn, artificial          66
# Other                      2
#                            2
# Name: LIGHT, dtype: int64

# %% [markdown]
# - The Weather condition related columns have few blank values, the LIGHT columns will be processed by combining the light condition with its artificial condition

# %% [markdown]
# ### Injury Information

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INJURY']].head()
# Out:
#             ACCLASS              IMPACTYPE        INVTYPE   INJURY
# 0  Non-Fatal Injury  Pedestrian Collisions         Driver     None
# 1  Non-Fatal Injury  Pedestrian Collisions      Passenger  Minimal
# 2             Fatal  Pedestrian Collisions     Pedestrian    Fatal
# 3  Non-Fatal Injury  Pedestrian Collisions  Vehicle Owner
# 4  Non-Fatal Injury  Pedestrian Collisions         Driver     None

# %%
data[['ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INJURY']].isnull().sum()
# Out:
# ACCLASS      0
# IMPACTYPE    0
# INVTYPE      0
# INJURY       0
# dtype: int64

# %%
data.ACCLASS.value_counts()
# Majority of the accidents are Non-Fatal
# Out:
# Non-Fatal Injury        10829
# Fatal                    1716
# Property Damage Only       12
# Name: ACCLASS, dtype: int64

# %%
data.IMPACTYPE.value_counts()
# Out:
# Pedestrian Collisions     5004
# Turning Movement          1885
# Rear End                  1280
# Cyclist Collisions        1258
# SMV Other                  945
# Angle                      891
# Approaching                638
# Sideswipe                  378
# Other                      140
# SMV Unattended Vehicle     138
# Name: IMPACTYPE, dtype: int64

# %%
data.INVTYPE.value_counts() # very few Blank Value
# Out:
# Driver                  5608
# Pedestrian              2076
# Passenger               1827
# Vehicle Owner           1415
# Cyclist                  544
# Motorcycle Driver        416
# Truck Driver             240
# Other Property Owner     206
# Other                    143
# Moped Driver              25
# Motorcycle Passenger      21
# Driver - Not Hit          13
# Wheelchair                10
#                            4
# In-Line Skater             3
# Trailer Owner              2
# Unknown - FTR              1
# Witness                    1
# Runaway - No Driver        1
# Pedestrian - Not Hit       1
# Name: INVTYPE, dtype: int64

# %%
data.INJURY.value_counts()
# All the blank values will be filled with "Unknown"
# Out:
# None       4576
# Major      4154
#            1472
# Minor       969
# Minimal     793
# Fatal       593
# Name: INJURY, dtype: int64

# %% [markdown]
# - The ACCLASS is a very important feature, In my next post I will build a classification model to predict the type of injury given the rest of the features.
#
# - The IMPACTYPE, INVTYPE, INJURY will also provide some input to the analysis and will be visualized in the coming sections

# %% [markdown]
# ### Types of Transporation involved in collision

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 
      'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 
      'EMERG_VEH', 'PASSENGER', 'VEHTYPE']].head()
# Out:
#   PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0        Yes                                               Yes
# 1        Yes                Yes
# 2        Yes                Yes
# 3        Yes                Yes
# 4        Yes                Yes
#
#   PASSENGER                      VEHTYPE
# 0            Municipal Transit Bus (TTC)
# 1       Yes                        Other
# 2
# 3       Yes                        Other
# 4       Yes    Automobile, Station Wagon

# %%
data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 
      'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 
      'EMERG_VEH', 'PASSENGER', 'VEHTYPE']].isnull().sum()
# Out:
# PEDESTRIAN       0
# CYCLIST          0
# AUTOMOBILE       0
# MOTORCYCLE       0
# TRUCK            0
# TRSN_CITY_VEH    0
# EMERG_VEH        0
# PASSENGER        0
# VEHTYPE          0
# dtype: int64

# %%
data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 
      'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 
      'EMERG_VEH', 'PASSENGER']].apply(pd.Series.value_counts)
# Out:
#      PEDESTRIAN  CYCLIST  AUTOMOBILE  MOTORCYCLE  TRUCK  TRSN_CITY_VEH  \
#            7557    11210        1188       11576  11761          11740
# Yes        5000     1347       11369         981    796            817
#
#      EMERG_VEH  PASSENGER
#          12542       7925
# Yes         15       4632

# %% [markdown]
# - I think, the columns PEDESTRIAN, CYCLIST, AUTOMOBILE, MOTORCYCLE, TRUCK, TRSN_CITY_VEH, EMERG_VEH and PASSENGER are simply "Yes" and " " type. Therefore the empty string (" ") can be convered into "No" to provide some insight.

# %%
data.VEHTYPE.value_counts() # Likely won't be much useful to provide insight into the data
# Out:
# Automobile, Station Wagon           5140
# Other                               4029
#                                     1707
# Bicycle                              537
# Motorcycle                           416
# Municipal Transit Bus (TTC)          199
# Truck - Open                         150
# Pick Up Truck                         88
# Passenger Van                         74
# Delivery Van                          35
# Truck - Closed (Blazer, etc)          31
# Street Car                            24
# Taxi                                  22
# Truck - Dump                          22
# Truck-Tractor                         20
# Moped                                 19
# Bus (Other) (Go Bus, Gray Coach)      11
# Truck (other)                          7
# Intercity Bus                          7
# Truck - Tank                           4
# Tow Truck                              4
# Police Vehicle                         3
# Construction Equipment                 2
# ...

# %% [markdown]
# ### Details and Reasons of Accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# - <b>Lets divide them in further subsections as follows:</b>
#
#         2.7.1: Automobile related information
#         a. INITDIR    - Initial direction of travel
#         b. MANOEUVER  - Vehicle manouever
#         c. DRIVACT    - Apparent driver action
#         d. DRIVCOND   - Driver condition
#         f. OFFSET     - Distance & direction of the accident
#
#         2.7.2: Pedestrian related information
#         a. PEDTYPE    - Pedestrian crash type - detail
#         b. PEDACT     - Pedestrian action
#         c. PEDCOND    - Condition of pedestrian
#
#         2.7.3: Cyclist related information
#         a. CYCLISTYPE - Cyclist crash type - detail
#         b. CYCACT     - Cyclist action
#         c. CYCCOND    - Cyclist condition
#
#         2.7.4: Reasons involved in the accident
#         a. SPEEDING   - Speeding related collision
#         b. AG_DRIV    - Aggressive & distracted driving
#         c. REDLIGHT   - Redlight related collision
#         d. ALCOHOL    - Alcohol related collision
#         e. DISABILITY - Disability related collision

# %% [markdown]
# #### Automobile related information

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['INITDIR', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'OFFSET']].head()
# Out:
#   INITDIR    MANOEUVER                       DRIVACT DRIVCOND OFFSET
# 0    West  Going Ahead              Driving Properly   Normal
# 1
# 2   South
# 3
# 4    West  Going Ahead  Failed to Yield Right of Way   Normal

# %%
data[['INITDIR', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'OFFSET']].isnull().sum()
# Out:
# INITDIR      0
# MANOEUVER    0
# DRIVACT      0
# DRIVCOND     0
# OFFSET       0
# dtype: int64

# %%
data.INITDIR.value_counts() # All the NaN will be filled with "Unknown"
# Out:
#            3788
# East       2224
# West       2127
# South      2078
# North      2014
# Unknown     326
# Name: INITDIR, dtype: int64

# %%
data.MANOEUVER.value_counts() # All the NaN will be filled with "Unknown"
# Out:
#                                        5443
# Going Ahead                            4138
# Turning Left                           1200
# Stopped                                 452
# Turning Right                           299
# Slowing or Stopping                     198
# Other                                   156
# Changing Lanes                          149
# Parked                                  138
# Unknown                                  97
# Reversing                                93
# Making U Turn                            69
# Overtaking                               67
# Pulling Away from Shoulder or Curb       31
# Merging                                  12
# Pulling Onto Shoulder or towardCurb      11
# Disabled                                  4
# Name: MANOEUVER, dtype: int64

# %%
data.DRIVACT.value_counts() # All the NaN will be filled with "Unknown"
# Out:
#                                 6356
# Driving Properly                2858
# Failed to Yield Right of Way    1035
# Lost control                     623
# Improper Turn                    389
# Other                            326
# Disobeyed Traffic Control        320
# Following too Close              205
# Exceeding Speed Limit            151
# Speed too Fast For Condition     137
# Improper Lane Change              80
# Improper Passing                  67
# Wrong Way on One Way Road          7
# Speed too Slow                     3
# Name: DRIVACT, dtype: int64

# %%
data.DRIVCOND.value_counts() # All the NaN will be filled with "Unknown"
# Out:
#                                       6359
# Normal                                3990
# Inattentive                           1061
# Unknown                                664
# Medical or Physical Disability         122
# Had Been Drinking                      113
# Ability Impaired, Alcohol               85
# Ability Impaired, Alcohol Over .08      82
# Fatigue                                 39
# Other                                   33
# Ability Impaired, Drugs                  9
# Name: DRIVCOND, dtype: int64

# %%
data.OFFSET.value_counts().nlargest(5)
# Out:
#                  11104
# 5 m South of        27
# 10 m North of       23
# 1 m East of         21
# 100 m East of       19
# Name: OFFSET, dtype: int64

# %% [markdown]
# - INITDIR, MANOEUVER, DRIVACT and DRIVCOND contains ~50% null values and will be filled with "Unknown"
#
# - OFFSET 11104 null values and will be droped out of the analysis later

# %% [markdown]
# #### Pedestrian related information

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['PEDTYPE', 'PEDACT', 'PEDCOND']].head()
# Out:
#                                              PEDTYPE  \
# 0
# 1
# 2  Vehicle is going straight thru inter.while ped...
# 3
# 4
#
#                          PEDACT PEDCOND
# 0
# 1
# 2  Crossing, no Traffic Control  Normal
# 3
# 4

# %%
data[['PEDTYPE', 'PEDACT', 'PEDCOND']].isnull().sum()
# Out:
# PEDTYPE    0
# PEDACT     0
# PEDCOND    0
# dtype: int64

# %%
data[['PEDTYPE', 'PEDACT', 'PEDCOND']].apply(pd.Series.value_counts).head(5)
# Out:
#                                     PEDTYPE   PEDACT  PEDCOND
#                                     10540.0  10543.0  10506.0
# Ability Impaired, Alcohol               NaN      NaN     30.0
# Ability Impaired, Alcohol Over .80      NaN      NaN      8.0
# Ability Impaired, Drugs                 NaN      NaN      6.0
# Coming From Behind Parked Vehicle       NaN     22.0      NaN

# %% [markdown]
# - PEDTYPE, PEDACT and  PEDCOND contains too many null values to process and will be droped out of the analysis later

# %% [markdown]
# #### Cyclist related information

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['CYCLISTYPE', 'CYCACT', 'CYCCOND']].head()
# Out:
#   CYCLISTYPE CYCACT CYCCOND
# 0
# 1
# 2
# 3
# 4

# %%
data[['CYCLISTYPE', 'CYCACT', 'CYCCOND']].isnull().sum()
# Out:
# CYCLISTYPE    0
# CYCACT        0
# CYCCOND       0
# dtype: int64

# %%
data[['CYCLISTYPE', 'CYCACT', 'CYCCOND']].apply(pd.Series.value_counts).head(5)
# Out:
#                                                     CYCLISTYPE   CYCACT  \
#                                                        12028.0  12026.0
# Ability Impaired, Alcohol                                  NaN      NaN
# Ability Impaired, Alcohol Over .80                         NaN      NaN
# Ability Impaired, Drugs                                    NaN      NaN
# Cyclist and Driver travelling in same direction...        39.0      NaN
#
#                                                     CYCCOND
#                                                     12027.0
# Ability Impaired, Alcohol                               3.0
# Ability Impaired, Alcohol Over .80                      1.0
# Ability Impaired, Drugs                                 2.0
# Cyclist and Driver travelling in same direction...      NaN

# %% [markdown]
# - CYCLISTYPE, CYCACT and CYCCOND contains too many null values to process and will be droped out of the analysis later

# %% [markdown]
# #### Reasons involved in the accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY']].head()
# Out:
#   SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY
# 0
# 1      Yes     Yes
# 2              Yes
# 3      Yes     Yes
# 4      Yes     Yes

# %%
data[['SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY']].isnull().sum()
# Out:
# SPEEDING      0
# AG_DRIV       0
# REDLIGHT      0
# ALCOHOL       0
# DISABILITY    0
# dtype: int64

# %%
data[['SPEEDING', 'AG_DRIV', 'REDLIGHT', 
      'ALCOHOL', 'DISABILITY']].apply(pd.Series.value_counts)
# Out:
#      SPEEDING  AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY
#         10367     6138     11498    12015       12201
# Yes      2190     6419      1059      542         356

# %% [markdown]
# - The SPEEDING, AG_DRIV, REDLIGHT, ALCOHOL, DISABILITY are simply "Yes" and " " types. Therefore the blank strings " " can be convered into "No" to provide some insight.

# %% [markdown]
# ### Index Columns

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['Index_', 'ACCNUM', 'FATAL_NO', 'FID']].head()
# Out:
#      Index_      ACCNUM  FATAL_NO    FID
# 0   6666068     1249781         0  12001
# 1   7542240     1311542         0  12002
# 2  80496257  5002235651        64  12003
# 3   7542241     1311542         0  12004
# 4   7542242     1311542         0  12005

# %% [markdown]
# - Index_, ACCNUM, FATAL_NO, and FID are just index's and since they won't provide any insight these columns will likely be excluded from the analysis.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# [back to top](#Table-of-Contents)

# %% [markdown]
# Attributes to be processed for cleaning and the details of the type of cleaning required
#     - 3.1 DATE: change dtype of DATE to DateTime dtype & creating MONTH attribute
#     - 3.2 INVAGE:
#         - Change the bins from 5 yr to 25 yr
#         - Assign categorical values eg 0-24) and so on
#     - 3.3 Empty string: fill the empty strings (" ") with "Unknown"
#     - 3.4 Fill NaN: replace all the " " to "No" in certain attributes
#     - 3.5 LIGHT: combine values of light and its artificial condition to fewer values
#     - 3.6 Create new DF: Insted of droping the irrelevant columns just select the relevant columns to a new dataframe

# %% [markdown]
# ### DATE

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data.DATE = pd.to_datetime(data.DATE)
data.DATE = data.DATE.dt.date
data['Date'] = pd.to_datetime(data['DATE'])
data['Month'] = data['Date'].map(lambda x:x.month)

# %%
data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data[['Date','YEAR','Month', 'Hour']].head()
# Out:
#         Date  YEAR  Month  Hour
# 0 2011-08-04  2011      8    23
# 1 2012-08-19  2012      8    23
# 2 2015-12-30  2015     12    23
# 3 2012-08-19  2012      8    23
# 4 2012-08-19  2012      8    23

# %%
data[['Date','YEAR','Month', 'Hour']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12557 entries, 0 to 12556
# Data columns (total 4 columns):
# Date     12557 non-null datetime64[ns]
# YEAR     12557 non-null int64
# Month    12557 non-null int64
# Hour     12557 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 392.5 KB

# %% [markdown]
# ### INVAGE

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data.INVAGE.value_counts()
# Out:
# unknown     2114
# 20 to 24    1134
# 25 to 29    1083
# 35 to 39     903
# 30 to 34     901
# 50 to 54     886
# 40 to 44     870
# 45 to 49     857
# 55 to 59     734
# 60 to 64     583
# 15 to 19     542
# 65 to 69     455
# 70 to 74     361
# 75 to 79     293
# 80 to 84     218
# 85 to 89     155
# 10 to 14     155
# 5 to 9       134
# 0 to 4       127
# 90 to 94      45
# Over 95        7
# Name: INVAGE, dtype: int64

# %%
data[["INVAGE"]] = data[["INVAGE"]].replace("0 to 4", "0-24")
data[["INVAGE"]] = data[["INVAGE"]].replace("5 to 9", "0-24")
data[["INVAGE"]] = data[["INVAGE"]].replace("10 to 14", "0-24")
data[["INVAGE"]] = data[["INVAGE"]].replace("15 to 19", "0-24")
data[["INVAGE"]] = data[["INVAGE"]].replace("20 to 24", "0-24")
data[["INVAGE"]] = data[["INVAGE"]].replace("25 to 29", "25-49")
data[["INVAGE"]] = data[["INVAGE"]].replace("30 to 34", "25-49")
data[["INVAGE"]] = data[["INVAGE"]].replace("35 to 39", "25-49")
data[["INVAGE"]] = data[["INVAGE"]].replace("40 to 44", "25-49")
data[["INVAGE"]] = data[["INVAGE"]].replace("45 to 49", "25-49")
data[["INVAGE"]] = data[["INVAGE"]].replace("50 to 54", "50-74")
data[["INVAGE"]] = data[["INVAGE"]].replace("55 to 59", "50-74")
data[["INVAGE"]] = data[["INVAGE"]].replace("60 to 64", "50-74")
data[["INVAGE"]] = data[["INVAGE"]].replace("65 to 69", "50-74")
data[["INVAGE"]] = data[["INVAGE"]].replace("70 to 74", "50-74")
data[["INVAGE"]] = data[["INVAGE"]].replace("75 to 79", "75-100")
data[["INVAGE"]] = data[["INVAGE"]].replace("80 to 84", "75-100")
data[["INVAGE"]] = data[["INVAGE"]].replace("85 to 89", "75-100")
data[["INVAGE"]] = data[["INVAGE"]].replace("90 to 94", "75-100")
data[["INVAGE"]] = data[["INVAGE"]].replace("Over 95", "75-100")
data[["INVAGE"]] = data[["INVAGE"]].replace("unknown", "Unknown")

# %%
data.INVAGE.value_counts()
# Out:
# 25-49      4614
# 50-74      3019
# Unknown    2114
# 0-24       2092
# 75-100      718
# Name: INVAGE, dtype: int64

# %% [markdown]
# ### Empty string

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['District', 'LOCCOORD', 'ACCLOC', 
      'TRAFFCTL', 'INVTYPE', 'INJURY',
      'RDSFCOND', 'VISIBILITY',
      'VEHTYPE', 'INITDIR', 'MANOEUVER',
      'DRIVACT', 'DRIVCOND']] = data[['District', 'LOCCOORD', 'ACCLOC', 
                                      'TRAFFCTL', 'INVTYPE', 'INJURY', 
                                      'RDSFCOND', 'VISIBILITY', 
                                      'VEHTYPE', 'INITDIR', 'MANOEUVER', 
                                      'DRIVACT', 'DRIVCOND']].replace([" "], ['Unknown'])

# %% [markdown]
# ### Fill NaN

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 
      'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 
      'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 
      'DISABILITY']] = data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 
                             'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 
                             'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 
                             'ALCOHOL', 'DISABILITY']].replace([' '], ['No'])

data[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 
      'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 
      'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 
      'DISABILITY']].apply(pd.Series.value_counts)
# Out:
#      PEDESTRIAN  CYCLIST  AUTOMOBILE  MOTORCYCLE  TRUCK  TRSN_CITY_VEH  \
# No         7557    11210        1188       11576  11761          11740
# Yes        5000     1347       11369         981    796            817
#
#      EMERG_VEH  PASSENGER  SPEEDING  AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY
# No       12542       7925     10367     6138     11498    12015       12201
# Yes         15       4632      2190     6419      1059      542         356

# %% [markdown]
# ### LIGHT

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
data.LIGHT.value_counts()
# Out:
# Daylight                7378
# Dark                    2754
# Dark, artificial        1902
# Dusk                     185
# Dusk, artificial         123
# Dawn                      77
# Daylight, artificial      68
# Dawn, artificial          66
# Other                      2
#                            2
# Name: LIGHT, dtype: int64

# %% [markdown]
# - Let's convert:
#     - Dark, artificial to Dark
#     - Dusk, artificial to Dusk
#     - Dawn, artificial to Dawn
#     - Daylight, artificial to Daylight
#     - " " to Other

# %%
data.LIGHT = data.LIGHT.replace(['Daylight, artificial', 
                                 'Dark, artificial', 
                                 'Dusk, artificial', 
                                 'Dawn, artificial', ' '], ['Daylight', 
                                                        'Dark', 
                                                        'Dusk', 
                                                        'Dawn', 'Other'])

# %%
data.LIGHT.value_counts()
# Out:
# Daylight    7446
# Dark        4656
# Dusk         308
# Dawn         143
# Other          4
# Name: LIGHT, dtype: int64

# %% [markdown]
# ### Create new DF

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
df = data[['YEAR', 'Month', 'Hour', 'Date', 'ROAD_CLASS', 'District', 
           'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'RDSFCOND', 
           'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'IMPACTYPE', 'VEHTYPE',
           'INVTYPE', 'INVAGE', 'INJURY', 'INITDIR', 'MANOEUVER', 
           'DRIVACT', 'DRIVCOND','PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 
           'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 
           'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 
           'DISABILITY', 'Ward_ID', 'Hood_ID', 'Division', 'ACCLASS']]

# %%
df.head()
# Out:
#    YEAR  Month  Hour       Date      ROAD_CLASS           District   LATITUDE  \
# 0  2011      8    23 2011-08-04  Major Arterial  Toronto East York  43.651545
# 1  2012      8    23 2012-08-19  Major Arterial        Scarborough  43.780445
# 2  2015     12    23 2015-12-30  Major Arterial  Toronto East York  43.682342
# 3  2012      8    23 2012-08-19  Major Arterial        Scarborough  43.780445
# 4  2012      8    23 2012-08-19  Major Arterial        Scarborough  43.780445
#
#    LONGITUDE      LOCCOORD           ACCLOC        ...        PASSENGER  \
# 0 -79.383490     Mid-Block          Unknown        ...               No
# 1 -79.300490  Intersection          Unknown        ...              Yes
# 2 -79.328266  Intersection  At Intersection        ...               No
# 3 -79.300490  Intersection          Unknown        ...              Yes
# 4 -79.300490  Intersection          Unknown        ...              Yes
#
# ...

# %%
df.shape
# Out:
# (12557, 40)

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Time and Age of person involved in the accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
f, ax = plt.subplots(nrows = 3, figsize = (10, 10))
f.subplots_adjust(hspace = 0.5)
f.suptitle("Number of Accident in the City of Toronto")
sns.countplot(df.YEAR, ax = ax[0], order = df.YEAR.value_counts().index, 
              palette="Blues_d")
sns.countplot(df.Month, ax = ax[1], order = df.Month.value_counts().index, 
              palette = "Blues_d")
sns.countplot(df.Hour, ax = ax[2], order = df.Hour.value_counts().index,
              palette = "Blues_d")
plt.savefig("Images/Year_Month_Hour_barplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, figsize = (10, 3))
f.subplots_adjust(hspace = 0.5)
f.suptitle("Age of person involved in accident in the City of Toronto")
sns.countplot(x="INVAGE", data=df, order = df.INVAGE.value_counts().index)
plt.savefig("Images/Age_barplot.jpeg")
plt.show()

# %% [markdown]
# ### Location of Accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
color = ['#377eb8', '#e41a1c', '#4daf4a']
fig1 = sns.lmplot(y ='LATITUDE', x ='LONGITUDE', hue='ACCLASS',
           data = df, height = 10, markers = '.', fit_reg = False, palette = color) 
plt.title("Scatter plot of Fatal vs Non-Fatal accidents in the City of Toronto")
fig1.savefig("Images/Fatal_Non-Fatal_Scatter.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, figsize = (12, 3))
f.subplots_adjust(hspace = 0.5)
f.suptitle("District of Accident in the City of Toronto")
sns.countplot(x="District", data=df)
plt.savefig("Images/District_barplot.jpeg")
plt.show()

# %% [markdown]
# ### Road Type and conditions during accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Type of Road at the accident location in the City of Toronto")
sns.violinplot(x = "YEAR", y = "ROAD_CLASS" , scale='count', data = df, cut=0, ax = ax[0], palette='Set1')
sns.violinplot(x = "Month", y = "ROAD_CLASS" , scale='count', data = df, cut=0, ax = ax[1],palette='Set1')
sns.violinplot(x = "Hour", y = "ROAD_CLASS" , scale='count', data = df, cut=0, ax = ax[2], palette='Set1')
plt.savefig("Images/Road_Type_Violinplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Location coordinate of the accident")
sns.violinplot(x = "YEAR", y = "LOCCOORD" , scale='count', data = df, cut=0, ax = ax[0])
sns.violinplot(x = "Month", y = "LOCCOORD" , scale='count', data = df, cut=0, ax = ax[1])
sns.violinplot(x = "Hour", y = "LOCCOORD" , scale='count', data = df, cut=0, ax = ax[2])
plt.savefig("Images/Location_coordinate_Violinplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Accident location in the City of Toronto")
sns.violinplot(x = "YEAR", y = "ACCLOC" , scale='count', data = df, cut=0, ax = ax[0], palette='Set2')
sns.violinplot(x = "Month", y = "ACCLOC" , scale='count', data = df, cut=0, ax = ax[1],palette='Set2')
sns.violinplot(x = "Hour", y = "ACCLOC" , scale='count', data = df, cut=0, ax = ax[2], palette='Set2')
plt.savefig("Images/Accident_location_Violinplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Road conditions during the Accident in the City of Toronto")
sns.violinplot(x = "YEAR", y = "RDSFCOND" , scale='count', data = df, cut=0, ax = ax[0], palette='Set2')
sns.violinplot(x = "Month", y = "RDSFCOND" , scale='count', data = df, cut=0, ax = ax[1],palette='Set2')
sns.violinplot(x = "Hour", y = "RDSFCOND" , scale='count', data = df, cut=0, ax = ax[2], palette='Set2')
plt.savefig("Images/Road_condition_Violinplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Traffic control during the Accident in the City of Toronto")
sns.violinplot(x = "YEAR", y = "TRAFFCTL" , scale='count', data = df, cut=0, ax = ax[0],)
sns.violinplot(x = "Month", y = "TRAFFCTL" , scale='count', data = df, cut=0, ax = ax[1])
sns.violinplot(x = "Hour", y = "TRAFFCTL" , scale='count', data = df, cut=0, ax = ax[2])
plt.savefig("Images/Traffic_control_Violinplot.jpeg")
plt.show()

# %% [markdown]
# ### Weather conditions during accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Weather conditions during the Accident in the City of Toronto")
sns.violinplot(x = "YEAR", y = "VISIBILITY" , scale='count', data = df, cut=0, ax = ax[0], 
               palette=sns.light_palette((210, 90, 60), input="husl"))
sns.violinplot(x = "Month", y = "VISIBILITY" , scale='count', data = df, cut=0, ax = ax[1],
               palette=sns.light_palette((210, 90, 60), input="husl"))
sns.violinplot(x = "Hour", y = "VISIBILITY" , scale='count', data = df, cut=0, ax = ax[2], 
               palette=sns.light_palette((210, 90, 60), input="husl"))
plt.savefig("Images/Visibility_Violinplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 8), sharey = True)
f.subplots_adjust(hspace = 0.5)
f.suptitle("Light conditions during the Accident in the City of Toronto")
sns.violinplot(x = "YEAR", y = "LIGHT" , scale='count', data = df, cut=0, ax = ax[0], 
               palette='dark')
sns.violinplot(x = "Month", y = "LIGHT" , scale='count', data = df, cut=0, ax = ax[1],
               palette="dark")
sns.violinplot(x = "Hour", y = "LIGHT" , scale='count', data = df, cut=0, ax = ax[2], 
               palette="dark")
plt.savefig("Images/LIGHT_Violinplot.jpeg")
plt.show()

# %% [markdown]
# ### Injury type of the accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
f, ax = plt.subplots(nrows = 3, figsize = (15, 10))
f.subplots_adjust(hspace = 1)
color = ['#377eb8', '#e41a1c', '#4daf4a']
sns.countplot(x="ACCLASS", data=df, ax=ax[0], palette=color).set_title('Type of Injury')
sns.countplot(x="INJURY", data=df, palette = "Blues_d",
              order = df.INJURY.value_counts().index, ax=ax[1]).set_title('Severity of Injury')
sns.countplot(x="IMPACTYPE", data=df, palette = "Blues_d",
              order = df.IMPACTYPE.value_counts().index, ax=ax[2]).set_title('Type of Impact')
plt.xticks(rotation=90)
plt.savefig("Images/Injury_barplot.jpeg")
plt.show()

# %% [markdown]
# ### Types of Transporation

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
df_sample = df[['PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 
      'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH']].apply(pd.Series.value_counts)
df_sample
# Out:
#      PEDESTRIAN  CYCLIST  AUTOMOBILE  MOTORCYCLE  TRUCK  TRSN_CITY_VEH  \
# No         7557    11210        1188       11576  11761          11740
# Yes        5000     1347       11369         981    796            817
#
#      EMERG_VEH
# No       12542
# Yes         15

# %%
my_colors = ['#377eb8', '#e41a1c']
df_sample.T.plot.bar(figsize = (12, 5), color=my_colors)
plt.xticks(rotation=360)
plt.title("Vehicle involved in the accident")
plt.savefig("Images/Involvement_barplot.jpeg")
plt.show()

# %%
f, ax = plt.subplots(nrows = 1, figsize = (15, 3))
f.subplots_adjust(hspace = 0.5)
f.suptitle("Type of vehicle involved in accident")
sns.countplot(x="VEHTYPE", data=df, palette = 'Blues_d', order = df.VEHTYPE.value_counts().index)
plt.savefig("Images/Type_of_vehicle_barplot.jpeg")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Reason of Accident

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
df_sample_2 = df[['PASSENGER', 
      'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL', 'DISABILITY']].apply(pd.Series.value_counts)
df_sample_2
# Out:
#      PASSENGER  SPEEDING  AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY
# No        7925     10367     6138     11498    12015       12201
# Yes       4632      2190     6419      1059      542         356

# %%
my_colors = ['#377eb8', '#e41a1c']
df_sample_2.T.plot.bar(figsize = (12, 5), color=my_colors)
plt.xticks(rotation=360)
plt.title("Reason of accident in the city of Toronto")
plt.savefig("Images/Reason_of_accident_barplot.jpeg")
plt.show()

# %% [markdown]
# ### Automobile related Information

# %% [markdown]
# [back to top](#Table-of-Contents)

# %%
f, ax = plt.subplots(nrows = 4, figsize = (15, 30))
f.subplots_adjust(hspace = 1.2)
#f.suptitle("Type of vehicle involved in accident")
sns.countplot(x="DRIVCOND", data=df, ax=ax[0], 
              palette = 'Blues_d', order = df.DRIVCOND.value_counts().index).set_title('Driver Condition')
sns.countplot(x="DRIVACT", data=df, ax=ax[1], 
              palette = 'Blues_d', order = df.DRIVACT.value_counts().index).set_title('Driver Action')
sns.countplot(x="MANOEUVER", data=df, ax=ax[2], 
              palette = 'Blues_d', order = df.MANOEUVER.value_counts().index).set_title('Manoeuver Direction')
sns.countplot(x="INITDIR", data=df, ax=ax[3], 
              palette = 'Blues_d', order = df.INITDIR.value_counts().index).set_title('Travel Direction')
plt.savefig("Images/Driver_conditions_barplot.jpeg")
for i in f.axes:
    plt.sca(i)
    plt.xticks(rotation=45)
plt.show()
